# %%
# !pip install faker
# !pip install contractions 
# !pip install simalign 
# !pip install ipywidgets
# !pip install transformers[torch] datasets
# Out:
# Requirement already satisfied: faker in c:\users\adminr\anaconda3\lib\site-packages (37.3.0)
# Requirement already satisfied: tzdata in c:\users\adminr\anaconda3\lib\site-packages (from faker) (2023.3)
# Requirement already satisfied: contractions in c:\users\adminr\anaconda3\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\adminr\anaconda3\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\adminr\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\adminr\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Requirement already satisfied: simalign in c:\users\adminr\anaconda3\lib\site-packages (0.4)
# Requirement already satisfied: numpy in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (1.26.4)
# Requirement already satisfied: torch in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (2.6.0)
# Requirement already satisfied: scipy in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (1.13.1)
# Requirement already satisfied: transformers in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (4.52.1)
# Requirement already satisfied: regex in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (2024.9.11)
# Requirement already satisfied: networkx in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (3.3)
# Requirement already satisfied: scikit-learn in c:\users\adminr\anaconda3\lib\site-packages (from simalign) (1.5.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adminr\anaconda3\lib\site-packages (from scikit-learn->simalign) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from scikit-learn->simalign) (3.5.0)
# Requirement already satisfied: filelock in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (4.11.0)
# Requirement already satisfied: jinja2 in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\adminr\anaconda3\lib\site-packages (from torch->simalign) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from sympy==1.13.1->torch->simalign) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (0.31.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (6.0.1)
# Requirement already satisfied: requests in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\adminr\appdata\roaming\python\python312\site-packages (from transformers->simalign) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\adminr\anaconda3\lib\site-packages (from transformers->simalign) (4.66.5)
# Requirement already satisfied: colorama in c:\users\adminr\anaconda3\lib\site-packages (from tqdm>=4.27->transformers->simalign) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adminr\anaconda3\lib\site-packages (from jinja2->torch->simalign) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers->simalign) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers->simalign) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers->simalign) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers->simalign) (2024.8.30)
# Requirement already satisfied: ipywidgets in c:\users\adminr\anaconda3\lib\site-packages (7.8.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\adminr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\adminr\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\adminr\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\adminr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\adminr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\adminr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\adminr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\adminr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\adminr\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\adminr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\adminr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\adminr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\adminr\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.3)
# Requirement already satisfied: six in c:\users\adminr\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets) (1.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\adminr\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\adminr\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\adminr\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\adminr\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.1)
# Requirement already satisfied: certifi in c:\users\adminr\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\adminr\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\adminr\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\adminr\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\adminr\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in c:\users\adminr\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adminr\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\adminr\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\adminr\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\adminr\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adminr\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adminr\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\adminr\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Requirement already satisfied: uri-template in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\adminr\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\adminr\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\adminr\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in c:\users\adminr\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\adminr\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# Requirement already satisfied: datasets in c:\users\adminr\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: transformers[torch] in c:\users\adminr\anaconda3\lib\site-packages (4.52.1)
# Requirement already satisfied: filelock in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (0.31.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (2024.9.11)
# Requirement already satisfied: requests in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\adminr\appdata\roaming\python\python312\site-packages (from transformers[torch]) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (4.66.5)
# Requirement already satisfied: torch<2.7,>=2.1 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (2.6.0)
# Requirement already satisfied: accelerate>=0.26.0 in c:\users\adminr\anaconda3\lib\site-packages (from transformers[torch]) (1.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\adminr\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\adminr\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\adminr\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in c:\users\adminr\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\adminr\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: psutil in c:\users\adminr\anaconda3\lib\site-packages (from accelerate>=0.26.0->transformers[torch]) (5.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\adminr\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\adminr\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers[torch]) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers[torch]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adminr\anaconda3\lib\site-packages (from requests->transformers[torch]) (2024.8.30)
# Requirement already satisfied: networkx in c:\users\adminr\anaconda3\lib\site-packages (from torch<2.7,>=2.1->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in c:\users\adminr\anaconda3\lib\site-packages (from torch<2.7,>=2.1->transformers[torch]) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\adminr\anaconda3\lib\site-packages (from torch<2.7,>=2.1->transformers[torch]) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\adminr\anaconda3\lib\site-packages (from torch<2.7,>=2.1->transformers[torch]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adminr\anaconda3\lib\site-packages (from sympy==1.13.1->torch<2.7,>=2.1->transformers[torch]) (1.3.0)
# Requirement already satisfied: colorama in c:\users\adminr\anaconda3\lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adminr\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adminr\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adminr\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\adminr\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\adminr\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adminr\anaconda3\lib\site-packages (from jinja2->torch<2.7,>=2.1->transformers[torch]) (2.1.3)

# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()

def generate_policy_entry():
    return {
        "Policy_ID": fake.uuid4(),
        "Policy_Text_EN": fake.text(max_nb_chars=500),
        "Policy_Text_FR": fake.text(max_nb_chars=500),
        "Policy_Text_ES": fake.text(max_nb_chars=500),
        "Summarized_Text": fake.text(max_nb_chars=100)
    }

data = [generate_policy_entry() for _ in range(500)]

# %%
df = pd.DataFrame(data)
df.to_csv(r"D:\Data science\Projects\Final Project\Csv\multilingual_insurance_policy_dataset.csv", index=False)

# %%
df.head()
# Out:
#                               Policy_ID  \
# 0  58124751-fe4e-4174-8ab6-50112f1a9cc2
# 1  44ba98db-1289-4b03-b6fe-18d3dfe1db17
# 2  a9736519-4549-4a48-a8cf-335d65cb6cae
# 3  6cb7c904-f8ae-4d9b-a8ed-9e0ebb01dec6
# 4  f68bde33-328e-4d67-a53a-1689dd4c4160
#
#                                       Policy_Text_EN  \
# 0  Political meeting garden. Material sense littl...
# 1  However candidate issue career out.\nPolice po...
# 2  Full authority industry beyond. Project campai...
# 3  Agent coach shoulder. Per state leader then en...
# 4  Congress five eat structure my lose scene. Mov...
#
#                                       Policy_Text_FR  \
# 0  Begin move risk situation film ahead. Civil co...
# 1  Benefit ago now good. Team prove position unde...
# 2  Something one fly he believe article few. Wear...
# 3  Strategy author environmental level. Keep walk...
# 4  This under nothing feel better believe. Role b...
#
#                                       Policy_Text_ES  \
# 0  Standard building husband sign police bring. R...
# 1  Best present guess business. Well station evid...
# 2  After learn result meet against meeting. Word ...
# 3  Side the better kitchen assume certain until. ...
# 4  Country stuff fill technology seem effort abou...
#
#                                      Summarized_Text
# 0  Official sense participant return evening. Rem...
# 1  Quality page share truth international. Leave ...
# 2  Popular miss magazine radio trip. Least send l...
# 3  Car parent southern follow. President try meet...
# 4  Option answer within. Its night class admit bu...

# %%
import re
import contractions

# %%
def normalize_text(text):
    if pd.isna(text): return ""
    text = text.lower()
    text = contractions.fix(text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
df = pd.read_csv(r"D:\Data science\Projects\Final Project\Csv\multilingual_insurance_policy_dataset.csv")
df['Policy_Text_EN'] = df['Policy_Text_EN'].apply(normalize_text)
df['Policy_Text_FR'] = df['Policy_Text_FR'].apply(normalize_text)
df['Policy_Text_ES'] = df['Policy_Text_ES'].apply(normalize_text)
df['Summarized_Text'] = df['Summarized_Text'].apply(normalize_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_en = TfidfVectorizer(max_features=500)
tfidf_fr = TfidfVectorizer(max_features=500)
tfidf_es = TfidfVectorizer(max_features=500)

tfidf_features_en = tfidf_en.fit_transform(df['Policy_Text_EN'])
tfidf_features_fr = tfidf_fr.fit_transform(df['Policy_Text_FR'])
tfidf_features_es = tfidf_es.fit_transform(df['Policy_Text_ES'])

# %%
df_policy_processed = pd.concat([
    df[['Policy_ID', 'Summarized_Text']],
    pd.DataFrame(tfidf_features_en.toarray(), columns=[f'EN_{x}' for x in tfidf_en.get_feature_names_out()]),
    pd.DataFrame(tfidf_features_fr.toarray(), columns=[f'FR_{x}' for x in tfidf_fr.get_feature_names_out()]),
    pd.DataFrame(tfidf_features_es.toarray(), columns=[f'ES_{x}' for x in tfidf_es.get_feature_names_out()])
], axis=1)

# %%
df.to_csv(r"D:\Data science\Projects\Final Project\Csv\Preprocessed Csv\Preprocessed_multilingual_insurance_policy_dataset.csv", index=False)
df.head()
# Out:
#                               Policy_ID  \
# 0  58124751-fe4e-4174-8ab6-50112f1a9cc2
# 1  44ba98db-1289-4b03-b6fe-18d3dfe1db17
# 2  a9736519-4549-4a48-a8cf-335d65cb6cae
# 3  6cb7c904-f8ae-4d9b-a8ed-9e0ebb01dec6
# 4  f68bde33-328e-4d67-a53a-1689dd4c4160
#
#                                       Policy_Text_EN  \
# 0  political meeting garden material sense little...
# 1  however candidate issue career out police poss...
# 2  full authority industry beyond project campaig...
# 3  agent coach shoulder per state leader then env...
# 4  congress five eat structure my lose scene movi...
#
#                                       Policy_Text_FR  \
# 0  begin move risk situation film ahead civil cou...
# 1  benefit ago now good team prove position under...
# 2  something one fly he believe article few wear ...
# 3  strategy author environmental level keep walk ...
# 4  this under nothing feel better believe role bl...
#
#                                       Policy_Text_ES  \
# 0  standard building husband sign police bring re...
# 1  best present guess business well station evide...
# 2  after learn result meet against meeting word t...
# 3  side the better kitchen assume certain until f...
# 4  country stuff fill technology seem effort abou...
#
#                                      Summarized_Text
# 0  official sense participant return evening rema...
# 1  quality page share truth international leave a...
# 2  popular miss magazine radio trip least send lo...
# 3  car parent southern follow president try meet ...
# 4  option answer within its night class admit bui...

# %%
from transformers import MBartTokenizer, MBartForConditionalGeneration
from datasets import Dataset

model_name = "sshleifer/tiny-mbart"
tokenizer = MBartTokenizer.from_pretrained(model_name)
model = MBartForConditionalGeneration.from_pretrained(model_name)

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples["Policy_Text_EN"], truncation=True, padding="max_length", max_length=512)
    targets = tokenizer(examples["Summarized_Text"], truncation=True, padding="max_length", max_length=128)
    inputs["labels"] = targets["input_ids"]
    return inputs

# %%
dataset = Dataset.from_pandas(df)
tokenized_datasets = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./mbart_policy_finetuned",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    num_train_epochs=1,
    weight_decay=0.01,
    logging_steps=10,
    save_strategy="no"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets,
    eval_dataset=tokenized_datasets
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 02:55, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>12.429700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>12.429400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>12.429600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>12.429500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>12.429200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>12.429000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>12.428700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>12.428300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>12.428000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>12.427600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>12.427200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>12.427000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>12.426400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>12.426200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>12.425600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>12.425600</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>12.425300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>12.424700</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>12.424600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>12.424600</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>12.424400</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>12.424000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>12.423700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>12.423900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>12.423900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=250, training_loss=12.426639678955079, metrics={'train_runtime': 176.1829, 'train_samples_per_second': 2.838, 'train_steps_per_second': 1.419, 'total_flos': 442368000.0, 'train_loss': 12.426639678955079, 'epoch': 1.0})

# %%
import pickle
with open(r"D:\Data science\Projects\Final Project\Pkl\Multilingual_Insurance_model.pkl", "wb") as f:
    pickle.dump(model, f)
print("✅ Fine-tuned model saved as Multilingual_Insurance_model.pkl")
